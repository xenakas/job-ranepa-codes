# %%
install.packages("remotes")
remotes::install_github("dvp17/mrio")
# Out:
# Скачанные бинарные пакеты находятся в
# 	/var/folders/sl/q4v92dy13b15fkbcnvclbs2w0000gp/T//RtmptPCzv9/downloaded_packages
# ...
# rlang      (1.1.1  -> 1.1.3 ) [CRAN]
# lifecycle  (1.0.3  -> 1.0.4 ) [CRAN]
# glue       (1.6.2  -> 1.7.0 ) [CRAN]
# cli        (3.6.1  -> 3.6.2 ) [CRAN]
# withr      (2.5.0  -> 3.0.0 ) [CRAN]
# utf8       (1.2.3  -> 1.2.4 ) [CRAN]
# fansi      (1.0.4  -> 1.0.6 ) [CRAN]
# stringi    (1.7.12 -> 1.8.3 ) [CRAN]
# Rcpp       (1.0.10 -> 1.0.12) [CRAN]
# cpp11      (0.4.3  -> 0.4.7 ) [CRAN]
# stringr    (1.5.0  -> 1.5.1 ) [CRAN]
# purrr      (1.0.1  -> 1.0.2 ) [CRAN]
# dplyr      (1.1.2  -> 1.1.4 ) [CRAN]
# plyr       (1.8.8  -> 1.8.9 ) [CRAN]
# tidyr      (1.3.0  -> 1.3.1 ) [CRAN]
# data.table (1.14.8 -> 1.15.2) [CRAN]
# Installing 16 packages: rlang, lifecycle, glue, cli, withr, utf8, fansi, stringi, Rcpp, cpp11, stringr, purrr, dplyr, plyr, tidyr, data.table
# Скачанные бинарные пакеты находятся в
# ...

# %%
setwd(dir = 'eora/')

# %%
exio_cc <- mrio::eoraloop(1995:2000, indicator = 200)
# Out:
# Error in menu(c("Yes", "No"), title = sprintf("This process will take about %.1f minutes. Do you want to proceed? \n", : menu() cannot be used non-interactively
# Traceback:
#
# 1. mrio::eoraloop(1995:2000, indicator = 200)
# 2. menu(c("Yes", "No"), title = sprintf("This process will take about %.1f minutes. Do you want to proceed? \n",
#  .     duration/60))
# 3. stop("menu() cannot be used non-interactively")
